# %% [markdown]
# # GDELT Raw Data File Collection

# %% [markdown]
# ### This file will follow the steps below to collect the gdelt data
# #### 1. This file will download the master file from official gdelt website.
# #### 2. Based on the user preference it will download the data from gdelt in compressed format.
# #### 3. Un-compressing the downloaded files
# #### 4. Combining the un-compressed files into one single csv file
# #### 5. Filter the data based on Actor1Code = 'HLH' and Actor2Code ='HLH' for healthcare events and eventRootCode IN ('10','11','12','13','14')
# #### 5. Push the combined csv file to NoSQL MongoDB

# %% [markdown]
# ### Download the Master file

# %% [markdown]
# #### Check if the old master file already present in the directory. If it's present then delete the old file and download the latest one from GDELT

# %%
import time
#import tracemalloc
#tracemalloc.start()
start_time = time.process_time()

import os
file_path = r".\master\masterfilelist.txt"
if os.path.isfile(file_path):
  os.remove(file_path)
  print("Old Master file existed and has been deleted")
else:
  print("Old Master file not found!")
# Out:
# Old Master file existed and has been deleted

# %% [markdown]
# #### Download the master file which maps the raw data files

# %%
import wget
path_master = r".\master"
wget.download("http://data.gdeltproject.org/gdeltv2/masterfilelist.txt", out = path_master)
# Out:
#   2% [.                                                                       ]  1785856 / 82717606
#   4% [...                                                                     ]  3538944 / 82717606
#   7% [.....                                                                   ]  6250496 / 82717606
#   9% [.......                                                                 ]  8077312 / 82717606
#  12% [.........                                                               ] 10452992 / 82717606
#  13% [..........                                                              ] 11550720 / 82717606
#  16% [...........                                                             ] 13254656 / 82717606
#  18% [.............                                                           ] 15572992 / 82717606
#  21% [...............                                                         ] 17465344 / 82717606
#  22% [................                                                        ] 18898944 / 82717606
# 100% [........................................................................] 82717606 / 82717606
# '.\\master/masterfilelist.txt'

# %% [markdown]
# ### Read the master file into a dataframe

# %%
import pandas as pd
header_list = ['A','B','C']
df = pd.read_csv(r".\master\masterfilelist.txt", sep= ' ', names = header_list)

# %% [markdown]
# #### Display the type of data that master file has and the amount of data it has

# %%
df.head()
# Out:
#           A                                 B  \
# 0    150383  297a16b493de7cf6ca809a7cc31d0b93
# 1    318084  bb27f78ba45f69a17ea6ed7755e9f8ff
# 2  10768507  ea8dde0beb0ba98810a92db068c0ce99
# 3    149211  2a91041d7e72b0fc6a629e2ff867b240
# 4    339037  dec3f427076b716a8112b9086c342523
#
#                                                    C
# 0  http://data.gdeltproject.org/gdeltv2/201502182...
# 1  http://data.gdeltproject.org/gdeltv2/201502182...
# 2  http://data.gdeltproject.org/gdeltv2/201502182...
# 3  http://data.gdeltproject.org/gdeltv2/201502182...
# 4  http://data.gdeltproject.org/gdeltv2/201502182...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774006 entries, 0 to 774005
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   A       774006 non-null  object
#  1   B       773951 non-null  object
#  2   C       773951 non-null  object
# dtypes: object(3)
# memory usage: 17.7+ MB

# %% [markdown]
# ### Fetch all the export table files of event data
# #### This code will download only the event data from GDELT

# %%
list_of_export_table = []

# %%
for i in df['C']:
    if 'export' in str(i):
        list_of_export_table.append(i)

# %%
len(list_of_export_table)
# Out:
# 257982

# %%
#shows only first 5 records fro reference
list_of_export_table[:5]
# Out:
# ['http://data.gdeltproject.org/gdeltv2/20150218230000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150218231500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150218233000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150218234500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219000000.export.CSV.zip']

# %% [markdown]
# ### Download the x number of files from today
# #### This will download all the files going back from the day (Exact time) the code is run

# %%
print("ENTER THE NUMEBR OF FILES YOU WANT TO DOWNLOAD")
num = input()
# Out:
# ENTER THE NUMEBR OF FILES YOU WANT TO DOWNLOAD
# 100

# %%
path_zip = r'.\zip_data'

# %%
import shutil
if len(os.listdir(path_zip)) == 0:
    print("Directory is empty")
else:
    shutil.rmtree(path_zip)

# %%
os.mkdir(path_zip)

# %%
for i in list_of_export_table[-int(num):]:
    wget.download(i, out = path_zip)
# Out:
# 100% [..............................................................................] 66884 / 66884

# %%
len(os.listdir(path_zip))
# Out:
# 100

# %% [markdown]
# ### Unzip the downloaded files to a seperate CSV folder

# %%
import shutil

# %%
path_csv = r'.\csv_data'

# %%
import shutil
if len(os.listdir(path_csv)) == 0:
    print("Directory is empty")
else:
    shutil.rmtree(path_csv)

# %%
os.mkdir(path_csv)

# %%
file_names = os.listdir(path_zip)

# %%
for i in file_names:
    shutil.unpack_archive(path_zip + '\\' + i, path_csv)

# %% [markdown]
# ### Combine all the CSV into one

# %%
header = ['GLOBALEVENTID', 
            'SQLDATE', 
            'MonthYear',
            'Year', 
            'FractionDate',
            'Actor1Code', 
            'Actor1Name', 
            'Actor1CountryCode',
            'Actor1KnownGroupCode',
            'Actor1EthnicCode',
            'Actor1Religion1Code',
            'Actor1Religion2Code',
            'Actor1Type1Code',
            'Actor1Type2Code',
            'Actor1Type3Code',
            'Actor2Code',
            'Actor2Name',
            'Actor2CountryCode',
            'Actor2KnownGroupCode',
            'Actor2EthnicCode',
            'Actor2Religion1Code',
            'Actor2Religion2Code',
            'Actor2Type1Code',
            'Actor2Type2Code',
            'Actor2Type3Code',
            'IsRootEvent',
            'EventCode',
            'EventBaseCode',
            'EventRootCode',
            'QuadClass',
            'GoldsteinScale',
            'NumMentions',
            'NumSources',
            'NumArticles',
            'AvgTone',
            'Actor1Geo_Type',
            'Actor1Geo_FullName',
            'Actor1Geo_CountryCode',
            'Actor1Geo_ADM1Code',
            'Actor1Geo_ADM2Code',
            'Actor1Geo_Lat',
            'Actor1Geo_Long',
            'Actor1Geo_FeatureID',
            'Actor2Geo_Type',
            'Actor2Geo_FullName',
            'Actor2Geo_CountryCode',
            'Actor2Geo_ADM1Code',
            'Actor2Geo_ADM2Code',
            'Actor2Geo_Lat',
            'Actor2Geo_Long',
            'Actor2Geo_FeatureID',
            'ActionGeo_Type',
            'ActionGeo_FullName',
            'ActionGeo_CountryCode',
            'ActionGeo_ADM1Code',
            'ActionGeo_ADM2Code',
            'ActionGeo_Lat',
            'ActionGeo_Long',
            'ActionGeo_FeatureID',
            'DATEADDED',
            'SOURCEURL']

# %%
len(header)
# Out:
# 61

# %%
import glob
files = os.path.join(path_csv, "*.csv")

# %%
files
# Out:
# '.\\csv_data\\*.csv'

# %%
files = glob.glob(files)

# %%
final_csv = pd.concat([pd.read_csv(f, sep = '\t', names = header) for f in files])

# %%
final_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114139 entries, 0 to 987
# Data columns (total 61 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   GLOBALEVENTID          114139 non-null  int64
#  1   SQLDATE                114139 non-null  int64
#  2   MonthYear              114139 non-null  int64
#  3   Year                   114139 non-null  int64
#  4   FractionDate           114139 non-null  float64
#  5   Actor1Code             102798 non-null  object
#  6   Actor1Name             102798 non-null  object
#  7   Actor1CountryCode      64323 non-null   object
#  8   Actor1KnownGroupCode   1583 non-null    object
#  9   Actor1EthnicCode       668 non-null     object
#  10  Actor1Religion1Code    1133 non-null    object
#  11  Actor1Religion2Code    323 non-null     object
#  12  Actor1Type1Code        48847 non-null   object
#  13  Actor1Type2Code        3320 non-null    object
#  14  Actor1Type3Code        86 non-null      object
#  15  Actor2Code             80920 non-null   object
#  16  Actor2Name             80920 non-null   object
#  17  Actor2CountryCode      50225 non-null   object
#  18  Actor2KnownGroupCode   1194 non-null    object
#  19  Actor2EthnicCode       491 non-null     object
#  20  Actor2Religion1Code    1049 non-null    object
#  21  Actor2Religion2Code    275 non-null     object
#  22  Actor2Type1Code        38398 non-null   object
#  23  Actor2Type2Code        2458 non-null    object
#  24  Actor2Type3Code        66 non-null      object
#  25  IsRootEvent            114139 non-null  int64
#  26  EventCode              114139 non-null  int64
#  27  EventBaseCode          114139 non-null  int64
#  28  EventRootCode          114139 non-null  int64
#  29  QuadClass              114139 non-null  int64
#  30  GoldsteinScale         114139 non-null  float64
#  31  NumMentions            114139 non-null  int64
#  32  NumSources             114139 non-null  int64
#  33  NumArticles            114139 non-null  int64
#  34  AvgTone                114139 non-null  float64
#  35  Actor1Geo_Type         114139 non-null  int64
#  36  Actor1Geo_FullName     99797 non-null   object
#  37  Actor1Geo_CountryCode  99833 non-null   object
#  38  Actor1Geo_ADM1Code     99833 non-null   object
#  39  Actor1Geo_ADM2Code     60252 non-null   object
#  40  Actor1Geo_Lat          99797 non-null   float64
#  41  Actor1Geo_Long         99820 non-null   float64
#  42  Actor1Geo_FeatureID    99833 non-null   object
#  43  Actor2Geo_Type         114139 non-null  int64
#  44  Actor2Geo_FullName     78659 non-null   object
#  45  Actor2Geo_CountryCode  78686 non-null   object
#  46  Actor2Geo_ADM1Code     78686 non-null   object
#  47  Actor2Geo_ADM2Code     40214 non-null   object
#  48  Actor2Geo_Lat          78659 non-null   float64
#  49  Actor2Geo_Long         78675 non-null   float64
#  50  Actor2Geo_FeatureID    78686 non-null   object
#  51  ActionGeo_Type         114139 non-null  int64
#  52  ActionGeo_FullName     110821 non-null  object
#  53  ActionGeo_CountryCode  110876 non-null  object
#  54  ActionGeo_ADM1Code     110876 non-null  object
#  55  ActionGeo_ADM2Code     56250 non-null   object
#  56  ActionGeo_Lat          110821 non-null  float64
#  57  ActionGeo_Long         110863 non-null  float64
#  58  ActionGeo_FeatureID    110876 non-null  object
#  59  DATEADDED              114139 non-null  int64
#  60  SOURCEURL              114139 non-null  object
# dtypes: float64(9), int64(16), object(36)
# memory usage: 54.0+ MB

# %%
len(final_csv)
# Out:
# 114139

# %% [markdown]
# #### Run the query on the combined data to filter the data based on healthcare events and event root code

# %%
import pandasql as pds

# %%
query = """SELECT * FROM final_csv WHERE EventRootCode IN ('10','11','12','13','14') AND (ACTOR1CODE = 'HLH' OR 'ACTOR2CODE' = 'HLH') """

# %%
new_df = pds.sqldf(query,globals())

# %%
new_df.head()
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0     1059874807  20220823     202208  2022     2022.6384        HLH
# 1     1059877831  20220823     202208  2022     2022.6384        HLH
# 2     1059877832  20220823     202208  2022     2022.6384        HLH
# 3     1059877834  20220823     202208  2022     2022.6384        HLH
# 4     1059879260  20220823     202208  2022     2022.6384        HLH
#
#          Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0          HOSPITAL              None                 None             None
# 1  REGISTERED NURSE              None                 None             None
# 2  REGISTERED NURSE              None                 None             None
# 3          HOSPITAL              None                 None             None
# 4            DOCTOR              None                 None             None
#
#    ... ActionGeo_Type                                 ActionGeo_FullName  \
# 0  ...              1                                             Jordan
# 1  ...              3  Halifax Health Medical Center, Florida, United...
# 2  ...              3             Volusia County, Florida, United States
# 3  ...              3  Halifax Health Medical Center, Florida, United...
# 4  ...              0                                               None
#
#   ActionGeo_CountryCode ActionGeo_ADM1Code ActionGeo_ADM2Code ActionGeo_Lat  \
# 0                    JO                 JO               None       31.0000
# 1                    US               USFL               None       29.2010
# 2                    US               USFL               None       29.0836
# 3                    US               USFL               None       29.2010
# 4                  None               None               None           NaN
#
#   ActionGeo_Long ActionGeo_FeatureID       DATEADDED  \
# 0        36.0000                  JO  20220823214500
# 1       -81.0543              294413  20220823221500
# 2       -81.2081              306921  20220823221500
# 3       -81.0543              294413  20220823221500
# 4            NaN                None  20220823223000
#
#                                            SOURCEURL
# 0  https://soaps.sheknows.com/general-hospital/re...
# 1  https://www.fox35orlando.com/news/florida-nurs...
# 2  https://www.fox35orlando.com/news/florida-nurs...
# 3  https://www.fox35orlando.com/news/florida-nurs...
# 4  https://www.cbc.ca/news/canada/prince-edward-i...
#
# [5 rows x 61 columns]

# %%
len(new_df)
# Out:
# 74

# %%
new_df.EventRootCode.unique()
# Out:
# array([11, 10, 12, 14, 13], dtype=int64)

# %%
new_df.head()
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0     1059874807  20220823     202208  2022     2022.6384        HLH
# 1     1059877831  20220823     202208  2022     2022.6384        HLH
# 2     1059877832  20220823     202208  2022     2022.6384        HLH
# 3     1059877834  20220823     202208  2022     2022.6384        HLH
# 4     1059879260  20220823     202208  2022     2022.6384        HLH
#
#          Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0          HOSPITAL              None                 None             None
# 1  REGISTERED NURSE              None                 None             None
# 2  REGISTERED NURSE              None                 None             None
# 3          HOSPITAL              None                 None             None
# 4            DOCTOR              None                 None             None
#
#    ... ActionGeo_Type                                 ActionGeo_FullName  \
# 0  ...              1                                             Jordan
# 1  ...              3  Halifax Health Medical Center, Florida, United...
# 2  ...              3             Volusia County, Florida, United States
# 3  ...              3  Halifax Health Medical Center, Florida, United...
# 4  ...              0                                               None
#
#   ActionGeo_CountryCode ActionGeo_ADM1Code ActionGeo_ADM2Code ActionGeo_Lat  \
# 0                    JO                 JO               None       31.0000
# 1                    US               USFL               None       29.2010
# 2                    US               USFL               None       29.0836
# 3                    US               USFL               None       29.2010
# 4                  None               None               None           NaN
#
#   ActionGeo_Long ActionGeo_FeatureID       DATEADDED  \
# 0        36.0000                  JO  20220823214500
# 1       -81.0543              294413  20220823221500
# 2       -81.2081              306921  20220823221500
# 3       -81.0543              294413  20220823221500
# 4            NaN                None  20220823223000
#
#                                            SOURCEURL
# 0  https://soaps.sheknows.com/general-hospital/re...
# 1  https://www.fox35orlando.com/news/florida-nurs...
# 2  https://www.fox35orlando.com/news/florida-nurs...
# 3  https://www.fox35orlando.com/news/florida-nurs...
# 4  https://www.cbc.ca/news/canada/prince-edward-i...
#
# [5 rows x 61 columns]

# %% [markdown]
# #### Push the data into a new CSV file

# %%
# %%time
new_df.to_csv(r".\GDELT_data.csv", index = False)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 7 ms

# %% [markdown]
# ### Export data to MongoDB collection

# %%
import pymongo

# %%
#Create connection to the mongodb client
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
client.list_database_names()
# Out:
# ['GDELT', 'admin', 'config', 'local']

# %%
db = client['GDELT']
db.list_collection_names()
# Out:
# ['balanced_data_all',
#  'balanced_data_no_protest_code_significant',
#  'raw_data_files']

# %%
if('raw_data_files' in db.list_collection_names()):
    db.raw_data_event.drop()
else:
    print("Collection does not exists!")

# %%
raw_data_files = db['raw_data_files']

# %%
#read the generated CSV
data = pd.read_csv(r".\GDELT_data.csv")

# %%
import json
final_data = json.loads(data.to_json(orient='records'))

# %%
# %%time
raw_data_files.insert_many(final_data)
end_time = time.process_time()
# Out:
# CPU times: total: 15.6 ms
# Wall time: 8.99 ms

# %%
total_time = end_time - start_time

# %%
total_time
# Out:
# 35.921875
